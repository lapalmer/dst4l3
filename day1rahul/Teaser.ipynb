# %% [markdown]
# #Teaser
#
# This is my first note.
#
# >This is my quote.
#
#     If you want something verbatim, put a tab and type.
#
# * first item in a list - use asterisk to make unnumbered list
# * second item
#
#
# 1. first item
# 2. second item
#
# http://www.google.com
#
# [hello google](http://www.google.com)
#
# ![alt text about my rabbit image](http://www.apbc.org.uk/sites/default/files/images/rabbit2.jpg "BUNNY")
#
# Here is something in `typewriter` text.
#
# ```python
#
# def f():
#     return None
#
# ```
#
# Let's say that $\alpha=3$
#
# Then we find that:
#
# $$ \alpha + 1 = 4 .$$

# %%
# !pip install seaborn
# Out:
# Downloading/unpacking seaborn
# ...
#   Running setup.py (path:/private/var/folders/rj/yff5kw6538ddv0p7kmm28ghc0000gq/T/pip_build_lisapalmer/seaborn/setup.py) egg_info for package seaborn
# ...
#   Running setup.py install for seaborn
# ...
# Cleaning up...

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
pd.set_option('display.width', 500)
pd.set_option('display.max_columns', 100)

# %% [markdown]
# Get Cheatsheet:
#
# from https://drive.google.com/folderview?id=0ByIrJAE4KMTtaGhRcXkxNHhmY2M&usp=sharing

# %%
df=pd.read_csv("all.csv", header=None,
               names=['rating', 'review_count', 'isbn', 'booktype','author_url', 'year', 'genre_urls', 'dir','rating_count', 'name'],
)
df.head()
# Out:
#    rating review_count        isbn         booktype                                         author_url  year                                         genre_urls                                                dir rating_count                                               name
# 0    4.40       136455  0439023483  good_reads:book  https://www.goodreads.com/author/show/153394.S...  2008  /genres/young-adult|/genres/science-fiction|/g...                dir01/2767052-the-hunger-games.html      2958974            The Hunger Games (The Hunger Games, #1)
# 1    4.41        16648  0439358078  good_reads:book  https://www.goodreads.com/author/show/1077326....  2003  /genres/fantasy|/genres/young-adult|/genres/fi...  dir01/2.Harry_Potter_and_the_Order_of_the_Phoe...      1284478  Harry Potter and the Order of the Phoenix (Har...
# ...

# %% [markdown]
# ##Vectorization
#
# The python numerical stack is based on a concept called vectorization. You have seen this in spreadsheets where you manipulate an entire column.
#
# Whats the idea? It is that cpu's have some ability to carry out multiple things at one time, and we should use it to increase speed. But its also something else: there is a simplicity of notation. For example, see the following

# %%
a=[1,2,3,4,5]
b=[11,12,13,14,15]
print type(a)
print "============="
for index,aitem in enumerate(a):
    print index, a[index]*b[index]
# Out:
# <type 'list'>
# ...
# 0 11
# 1 24
# 2 39
# 3 56
# 4 75

# %%
a=np.array([1,2,3,4,5])
print type(a)
b=np.array([11,12,13,14,15])
c=a*b
print c
# Out:
# <type 'numpy.ndarray'>
# [11 24 39 56 75]

# %%
a+1
# Out:
# array([2, 3, 4, 5, 6])

# %% [markdown]
# ##Pandas

# %%
df=pd.read_csv("all.csv", header=None,
               names=["rating", 'review_count', 'isbn', 'booktype','author_url', 'year', 'genre_urls', 'dir','rating_count', 'name'],
)
df.head()
# Out:
#    rating review_count        isbn         booktype                                         author_url  year                                         genre_urls                                                dir rating_count                                               name
# 0    4.40       136455  0439023483  good_reads:book  https://www.goodreads.com/author/show/153394.S...  2008  /genres/young-adult|/genres/science-fiction|/g...                dir01/2767052-the-hunger-games.html      2958974            The Hunger Games (The Hunger Games, #1)
# 1    4.41        16648  0439358078  good_reads:book  https://www.goodreads.com/author/show/1077326....  2003  /genres/fantasy|/genres/young-adult|/genres/fi...  dir01/2.Harry_Potter_and_the_Order_of_the_Phoe...      1284478  Harry Potter and the Order of the Phoenix (Har...
# ...

# %% [markdown]
# Notice we have a table! A spreadsheet! And it indexed the rows. Lets see the types of the columns...
#
# ![](files/pandastruct.png)

# %%
df.dtypes
# Out:
# rating          float64
# review_count     object
# isbn             object
# booktype         object
# author_url       object
# year            float64
# genre_urls       object
# dir              object
# rating_count     object
# name             object
# dtype: object

# %%
df.shape
# Out:
# (6000, 10)

# %%
df.columns
# Out:
# Index([u'rating', u'review_count', u'isbn', u'booktype', u'author_url', u'year', u'genre_urls', u'dir', u'rating_count', u'name'], dtype='object')

# %%
df.rating
# Out:
# 0     4.40
# 1     4.41
# 2     3.56
# 3     4.23
# 4     4.23
# 5     4.25
# 6     4.22
# 7     4.38
# 8     3.79
# 9     4.18
# 10    4.03
# 11    3.72
# 12    4.36
# 13    4.05
# 14    3.72
# ...
# 5985    3.61
# 5986    4.06
# 5987    4.26
# 5988    4.34
# 5989    3.36
# 5990    4.12
# 5991    4.20
# 5992    3.89
# 5993    4.09
# 5994    4.37
# 5995    4.17
# 5996    3.99
# 5997    3.78
# 5998    3.91
# 5999    4.35
# Name: rating, Length: 6000, dtype: float64

# %%
type(df.rating), type(df)
# Out:
# (pandas.core.series.Series, pandas.core.frame.DataFrame)

# %%
df[['rating', 'name']].sort(['rating'], ascending=False)
# Out:
#       rating                                               name
# 1718    5.00                         An Elephant Is On My House
# 2145    5.00                   A Book About Absolutely Nothing.
# 5564    5.00               Untainted (Photographer Trilogy, #3)
# 2903    5.00              Obscured Darkness (Family Secrets #2)
# 2909    5.00                                     Family Secrets
# 4473    5.00                                    Patience's Love
# 5692    5.00  Abstraction In Theory - Laws Of Physical Trans...
# 2868    4.94                    Nik Nassa & the Mark of Destiny
# 2865    4.93                LaÃ§os fortes e decisÃµes difÃ­ceis
# 2920    4.93                                The Years Distilled
# 3712    4.93                                        Blade Heart
# 2034    4.92                                    Happy Halloween
# 3254    4.92                       Blackout (Talisman of El #2)
# 4405    4.88                                       My Two Cents
# ...

# %%
# Now I have everything with a rating greater than 3 with the rating and name
df[['rating', 'name']][df.rating > 3.0]
# Out:
#       rating                                               name
# 0       4.40            The Hunger Games (The Hunger Games, #1)
# 1       4.41  Harry Potter and the Order of the Phoenix (Har...
# 2       3.56                            Twilight (Twilight, #1)
# 3       4.23                              To Kill a Mockingbird
# 4       4.23                                Pride and Prejudice
# 5       4.25                                 Gone with the Wind
# 6       4.22  The Chronicles of Narnia (Chronicles of Narnia...
# 7       4.38                                    The Giving Tree
# 8       3.79                                        Animal Farm
# 9       4.18  The Hitchhiker's Guide to the Galaxy (Hitchhik...
# 10      4.03                                Memoirs of a Geisha
# 11      3.72             The Da Vinci Code (Robert Langdon, #2)
# 12      4.36                                     The Book Thief
# 13      4.05  Alice's Adventures in Wonderland & Through the...
# ...

# %%
# what fraction has ratings greater than 4 is 42%
100*np.mean(df.rating < 4.0)
# Out:
# 42.299999999999997

# %%
# now I've added rating count to the table and defined it as dfnew
dfnew=df[['rating', 'name', 'rating_count']]

# %%
np.sum(dfnew.rating_count=='None')
# Out:
# 2

# %%
dfnew[df.rating_count=='None']
# Out:
#       rating  name rating_count
# 3643     NaN  None         None
# 5282     NaN  None         None

# %%
dfnew=dfnew[df.rating_count!='None']

# %%
dfnew.rating_count=dfnew.rating_count.astype(np.int64)
dfnew.dtypes
# Out:
# rating          float64
# name             object
# rating_count      int64
# dtype: object

# %%
dftemp=dfnew[(dfnew.rating > 3.0) & (dfnew.rating_count > 1000)]
dftemp[dftemp.rating_count < 10000]
# Out:
#       rating                                               name  rating_count
# 108     4.50                  The Compleat Works of Wllm Shkspr          5617
# 214     4.21                               The Secret Magdalene          2404
# 285     4.46                              Flow Down Like Silver          1304
# 385     4.32                                      Houdini Heart          1184
# 683     4.13                            How Green Was My Valley          8242
# 779     4.34      The Time Quartet Box Set (Time Quartet, #1-4)          9132
# 849     4.25                            Tales of H.P. Lovecraft          5158
# 852     3.68                                  The Tale of Genji          5485
# 874     3.72                                    The Zombie Room          7445
# 884     3.65                                  The Elephant Tree          6280
# 903     3.98         The Gormenghast Novels (Gormenghast, #1-3)          5416
# ...

# %%
df.dtypes
# Out:
# rating          float64
# review_count     object
# isbn             object
# booktype         object
# author_url       object
# year            float64
# genre_urls       object
# dir              object
# rating_count     object
# name             object
# dtype: object

# %%
dftemp2=dftemp.sort(['rating'], ascending=False)
dftemp2.head(n=100)
# Out:
#       rating                                               name  rating_count
# 249     4.80                     The Complete Calvin and Hobbes         22674
# 1853    4.76                                    ESV Study Bible          7343
# 1595    4.76     Words of Radiance (The Stormlight Archive, #2)         32304
# 4944    4.75                                  Calvin and Hobbes         18637
# 1993    4.75                           Mark of the Lion Trilogy          7044
# 4084    4.75                       The Absolute Sandman, Vol. 4          3661
# 1551    4.73           Harry Potter Boxset (Harry Potter, #1-7)        141954
# 3203    4.72                       The Absolute Sandman, Vol. 3          3805
# 5957    4.72                              J. R. Ward Collection          1788
# 3207    4.71                The Indispensable Calvin and Hobbes         12709
# 3301    4.71  Harry Potter Hardcover Boxed Set, Books 1-6 (H...         20354
# ...

# %%
df.rating_count.isnull().sum()
# Out:
# 0

# %%
df[df.rating > 4.5]
# Out:
#       rating review_count        isbn         booktype                                         author_url  year                                         genre_urls                                                dir rating_count                                               name
# 17      4.58         1314  0345538374  good_reads:book  https://www.goodreads.com/author/show/656983.J...  1973  /genres/fantasy|/genres/classics|/genres/scien...       dir01/30.J_R_R_Tolkien_4_Book_Boxed_Set.html        68495                    J.R.R. Tolkien 4-Book Boxed Set
# 162     4.55        15777  075640407X  good_reads:book  https://www.goodreads.com/author/show/108424.P...  2007                    /genres/fantasy|/genres/fiction             dir02/186074.The_Name_of_the_Wind.html       210018  The Name of the Wind (The Kingkiller Chronicle...
# ...

# %%
# to get a series of ratings
ratingseries=df.rating[df.rating.notnull()]
ratingseries
# Out:
# 0     4.40
# 1     4.41
# 2     3.56
# 3     4.23
# 4     4.23
# 5     4.25
# 6     4.22
# 7     4.38
# 8     3.79
# 9     4.18
# 10    4.03
# 11    3.72
# 12    4.36
# 13    4.05
# 14    3.72
# ...
# 5985    3.61
# 5986    4.06
# 5987    4.26
# 5988    4.34
# 5989    3.36
# 5990    4.12
# 5991    4.20
# 5992    3.89
# 5993    4.09
# 5994    4.37
# 5995    4.17
# 5996    3.99
# 5997    3.78
# 5998    3.91
# 5999    4.35
# Name: rating, Length: 5998, dtype: float64

# %%
# now I'm getting the values
vals=ratingseries.values
type(vals)
# Out:
# numpy.ndarray

# %%
#histogram of the rating series values
plt.hist(vals);

# %%
print type(vals)
vals
# Out:
# <type 'numpy.ndarray'>
# array([ 4.4 ,  4.41,  3.56, ...,  3.78,  3.91,  4.35])

# %% [markdown]
# But one dosent have to

# %%
# can get a histogram this way too - the simplest way to do it - the semicolon at the end suppresses the output
df.rating.hist(bins=100);

# %%
# seaborn is what gives us the functionality to do this - a poster is bigger and very nice - other styles are "white", "ticks"
# "dark" -- can drag that histogram onto your desktop, will be a .png file -- red line and Mean at top is the legend
sns.set_context("notebook")
meanrat=df.rating.mean()
print meanrat, np.mean(df.rating), df.rating.median()
with sns.axes_style("whitegrid"):
    df.rating.hist(bins=50, alpha=0.4);
    plt.axvline(meanrat, 0, 1.0, color='r', label='Mean')
    plt.xlabel("average rating of book")
    plt.ylabel("Counts")
    plt.title("Ratings Histogram")
    plt.legend()
    #sns.despine()
# Out:
# 4.04220073358 4.04220073358 4.05
